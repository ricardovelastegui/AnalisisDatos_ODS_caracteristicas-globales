# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardovelastegui/AnalisisDatos_ODS_caracteristicas-globales/blob/main/Analisis_Exploraci%C3%B3n_de_caracter%C3%ADsticas_Globales_Plaza_y_Velastegui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Librerías

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# # Cargar datos

# %%
df = pd.read_excel('/content/drive/MyDrive/ciap/datosinerrores2.xlsx')

# %%
'''def quitar(x):
  return x.strip('$ ')

def reemplazo(x):
  return x.replace(',','')

df['GDP'] = df['GDP'].apply(str)
df['GDP'] = df['GDP'].apply(quitar)
df['GDP'] = df['GDP'].apply(reemplazo)
#df['GDP'] = df['GDP'].apply(int)
df['GDP']'''
# Out:
# "def quitar(x):\n  return x.strip('$ ')\n\ndef reemplazo(x):\n  return x.replace(',','')\n\ndf['GDP'] = df['GDP'].apply(str)\ndf['GDP'] = df['GDP'].apply(quitar)\ndf['GDP'] = df['GDP'].apply(reemplazo)\n#df['GDP'] = df['GDP'].apply(int)\ndf['GDP']"

# %% [markdown]
# ## Mostrar primeras filas

# %%
df.head()
# Out:
#                Country  Density(P/Km2) Armed Forces size  \
# 0  Antigua and Barbuda             223                 0
# 1            Argentina              17               105
# 2             Barbados             668                 1
# 3               Belize              17                 2
# 4              Bolivia              11                71
#
#   Co2-Emissions(megatoneladas)     CPI  CPI Change (%)              GDP $  \
# 0                          557  113.81           0.012    $1,727,759,259
# 1                      201.348  232.75           0.535  $449,663,446,954
# 2                        1.276  134.09           0.041    $5,209,000,000
# 3                          568  105.68          -0.009    $1,879,613,600
# 4                       21.606  148.32           0.018   $40,895,322,865
#
#    Gross primary education enrollment (%)  \
# 0                                   1.050
# 1                                   1.097
# 2                                   0.994
# ...

# %% [markdown]
# ## Mostrar últimas filas

# %%
df.tail()
# Out:
#                 Country  Density(P/Km2) Armed Forces size  \
# 28             Suriname               4                 2
# 29  Trinidad and Tobago             273                 4
# 30        United States              36         1,359,000
# 31              Uruguay              20                22
# 32            Venezuela              32               343
#
#    Co2-Emissions(megatoneladas)       CPI  CPI Change (%)  \
# 28                        1.738    294.66           0.220
# 29                       43.868    141.75           0.010
# 30                    5,006,302    117.24           0.075
# 31                        6.766    202.92           0.079
# 32                      164.175  2,740,27           2.549
#
#                    GDP $  Gross primary education enrollment (%)  \
# 28       $3,985,250,737                                    1.088
# 29      $24,100,202,834                                    1.062
# ...

# %% [markdown]
# # Muestra aleatoria de filas

# %%
df.sample(5)
# Out:
#         Country  Density(P/Km2) Armed Forces size  \
# 26  Saint Lucia             301               NaN
# 28     Suriname               4                 2
# 14  El Salvador             313                42
# 10         Cuba             106                76
# 22    Nicaragua              55                12
#
#    Co2-Emissions(megatoneladas)     CPI  CPI Change (%)              GDP $  \
# 26                          414  110.13           0.019    $2,122,450,630
# 28                        1.738  294.66           0.220    $3,985,250,737
# 14                        7.169  111.23           0.001   $27,022,640,000
# 10                       28.284     NaN             NaN  $100,023,000,000
# 22                        5.592  162.74           0.054   $12,520,915,291
#
#     Gross primary education enrollment (%)  \
# 26                                   1.026
# 28                                   1.088
# 14                                   0.948
# ...

# %% [markdown]
# ## Cantidad de filas y columnas

# %%
df.shape
# Out:
# (33, 21)

# %% [markdown]
# ## Revisión de índices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %% [markdown]
# ## Revisión de columnas

# %%
df.columns
# Out:
# Index(['Country', 'Density(P/Km2)', 'Armed Forces size',
#        'Co2-Emissions(megatoneladas)', 'CPI', 'CPI Change (%)', 'GDP $',
#        'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Life expectancy', 'Maternal mortality ratio', 'Minimum wage',
#        'Out of pocket health expenditure', 'Physicians per thousand',
#        'Population', 'Population: Labor force participation (%)',
#        'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
#        'Urban_population'],
#       dtype='object')

# %% [markdown]
# ## Eliminación de columnas

# %%
df = df.drop(['Population: Labor force participation (%)',
       'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
       'Urban_population'],axis=1)

# %%
df.head()
# Out:
#                Country  Density(P/Km2) Armed Forces size  \
# 0  Antigua and Barbuda             223                 0
# 1            Argentina              17               105
# 2             Barbados             668                 1
# 3               Belize              17                 2
# 4              Bolivia              11                71
#
#   Co2-Emissions(megatoneladas)     CPI  CPI Change (%)              GDP $  \
# 0                          557  113.81           0.012    $1,727,759,259
# 1                      201.348  232.75           0.535  $449,663,446,954
# 2                        1.276  134.09           0.041    $5,209,000,000
# 3                          568  105.68          -0.009    $1,879,613,600
# 4                       21.606  148.32           0.018   $40,895,322,865
#
#    Gross primary education enrollment (%)  \
# 0                                   1.050
# 1                                   1.097
# 2                                   0.994
# ...

# %% [markdown]
# ## Eliminación de filas

# %%
#df = df.drop([10348,10349],axis=0)

# %%
#df.tail()

# %% [markdown]
# ## Obtener filas
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### iloc | Filas

# %%
df.head()
# Out:
#                Country  Density(P/Km2) Armed Forces size  \
# 0  Antigua and Barbuda             223                 0
# 1            Argentina              17               105
# 2             Barbados             668                 1
# 3               Belize              17                 2
# 4              Bolivia              11                71
#
#   Co2-Emissions(megatoneladas)     CPI  CPI Change (%)              GDP $  \
# 0                          557  113.81           0.012    $1,727,759,259
# 1                      201.348  232.75           0.535  $449,663,446,954
# 2                        1.276  134.09           0.041    $5,209,000,000
# 3                          568  105.68          -0.009    $1,879,613,600
# 4                       21.606  148.32           0.018   $40,895,322,865
#
#    Gross primary education enrollment (%)  \
# 0                                   1.050
# 1                                   1.097
# 2                                   0.994
# ...

# %%
# Una sola fila
#df.iloc[0,:] # Serie
df.iloc[[0],:] # Dataframe
# Out:
#                Country  Density(P/Km2) Armed Forces size  \
# 0  Antigua and Barbuda             223                 0
#
#   Co2-Emissions(megatoneladas)     CPI  CPI Change (%)            GDP $  \
# 0                          557  113.81           0.012  $1,727,759,259
#
#    Gross primary education enrollment (%)  \
# 0                                    1.05
#
#    Gross tertiary education enrollment (%)  Infant mortality  ...  \
# 0                                    0.248               5.0  ...
#
#    Maternal mortality ratio  Minimum wage Out of pocket health expenditure  \
# 0                      42.0          3.04                            0.243
#
#    Physicians per thousand  Population  \
# 0                     2.76      97.118
#
#   Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       NaN            0.165            0.43
#
#    Unemployment rate  Urban_population
# 0                NaN              23.8
# ...

# %%
# Rango de filas
df.iloc[0:5,:]
# Out:
#                Country  Density(P/Km2) Armed Forces size  \
# 0  Antigua and Barbuda             223                 0
# 1            Argentina              17               105
# 2             Barbados             668                 1
# 3               Belize              17                 2
# 4              Bolivia              11                71
#
#   Co2-Emissions(megatoneladas)     CPI  CPI Change (%)              GDP $  \
# 0                          557  113.81           0.012    $1,727,759,259
# 1                      201.348  232.75           0.535  $449,663,446,954
# 2                        1.276  134.09           0.041    $5,209,000,000
# 3                          568  105.68          -0.009    $1,879,613,600
# 4                       21.606  148.32           0.018   $40,895,322,865
#
#    Gross primary education enrollment (%)  \
# 0                                   1.050
# 1                                   1.097
# 2                                   0.994
# ...

# %%
# Filas específicas
df.iloc[[13],3]
# Out:
# 13    41.155
# Name: Co2-Emissions(megatoneladas), dtype: object

# %% [markdown]
# ### loc | Filas

# %%
df2 = df.set_index("Country")

# %%
df2.head()
# Out:
#                      Density(P/Km2) Armed Forces size  \
# Country
# Antigua and Barbuda             223                 0
# Argentina                        17               105
# Barbados                        668                 1
# Belize                           17                 2
# Bolivia                          11                71
#
#                     Co2-Emissions(megatoneladas)     CPI  CPI Change (%)  \
# Country
# Antigua and Barbuda                          557  113.81           0.012
# Argentina                                201.348  232.75           0.535
# Barbados                                   1.276  134.09           0.041
# Belize                                       568  105.68          -0.009
# Bolivia                                   21.606  148.32           0.018
#
#                                  GDP $  \
# Country
# Antigua and Barbuda    $1,727,759,259
# Argentina            $449,663,446,954
# Barbados               $5,209,000,000
# ...

# %%
# Una sola fila
#df2.loc["Sketch - Draw & Paint",:] #Serie
df2.loc[["Ecuador"],:] #Dataframe
# Out:
#          Density(P/Km2) Armed Forces size Co2-Emissions(megatoneladas)  \
# Country
# Ecuador              71                41                       41.155
#
#             CPI  CPI Change (%)              GDP $  \
# Country
# Ecuador  124.14           0.003  $107,435,665,000
#
#          Gross primary education enrollment (%)  \
# Country
# Ecuador                                   1.033
#
#          Gross tertiary education enrollment (%)  Infant mortality  \
# Country
# Ecuador                                    0.449              12.2
#
#          Life expectancy  Maternal mortality ratio Minimum wage  \
# Country
# Ecuador             76.8                      59.0         2.46
#
#          Out of pocket health expenditure  Physicians per thousand  \
# Country
# Ecuador                             0.437                     2.04
#
#          Population  Population: Labor force participation (%)  \
# Country
# Ecuador  17,373,662                                       0.68
#
# ...

# %%
# Filas específicas
df2.loc[["Ecuador","Canada"],:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-391c4de88caf> in <cell line: 0>()
#       1 # Filas específicas
# ----> 2 df2.loc[["Ecuador","Canada"],:]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## Obtener columnas

# %% [markdown]
# ## Hipotesis

# %% [markdown]
# *Hipotesis 1*

# %%
def quitar(x):
  return x.strip(' ')

def reemplazo(x):
  return x.replace(',','')
df['Co2-Emissions(megatoneladas)'] = df['Co2-Emissions(megatoneladas)'].apply(str)
df['Co2-Emissions(megatoneladas)'] = df['Co2-Emissions(megatoneladas)'].apply(quitar)
df['Co2-Emissions(megatoneladas)'] = df['Co2-Emissions(megatoneladas)'].apply(reemplazo)
df['Co2-Emissions(megatoneladas)'] = round(df['Co2-Emissions(megatoneladas)'].apply(float),2)
df['Co2-Emissions(megatoneladas)']
matrizH1 =df.iloc[:,[0,3,10]]
print(matrizH1)
# Out:
#                              Country  Co2-Emissions(megatoneladas)  \
# 0                Antigua and Barbuda                        557.00
# 1                          Argentina                        201.35
# 2                           Barbados                          1.28
# 3                             Belize                        568.00
# 4                            Bolivia                         21.61
# 5                             Brazil                        462.30
# 6                             Canada                        544.89
# 7                              Chile                         85.82
# 8                           Colombia                         97.81
# 9                         Costa Rica                          8.02
# 10                              Cuba                         28.28
# 11                          Dominica                        180.00
# 12                Dominican Republic                         25.26
# ...

# %%
#Promedio de emisiones C02-America comparado con Ecuador
mediaCo2= df['Co2-Emissions(megatoneladas)'].mean()
#Ecu_med=df.loc[13, 'Co2-Emissions']
print(f'El promedio de la emsiones de CO2 en America es {round(mediaCo2,2)} y la media de emisiones de CO2 de Ecuador es {df.loc[13, "Co2-Emissions(megatoneladas)"]} millones de toneladas ')
# Out:
# El promedio de la emsiones de CO2 en America es 151844.19 y la media de emisiones de CO2 de Ecuador es 41.16 millones de toneladas

# %%
# #Promedio de esperanza de vida de America comparado con Ecuador
mediaVida= df['Life expectancy'].mean()
#Ecu_med=df.loc[13, 'Co2-Emissions']
print(f'El promedio de esperanza de vida en America es {round(mediaVida,2)} y la media de esperanza de vida en el Ecuador es {df.loc[13, "Life expectancy"]} ')
# Out:
# El promedio de esperanza de vida en America es 75.2 y la media de esperanza de vida en el Ecuador es 76.8

# %%
#Se puede observar que a mayor cantidad de CO2 el tiempo de vida se reduce.
#El pais con mayor emision de co2
top=df['Co2-Emissions(megatoneladas)'].max()
ind_top= df['Co2-Emissions(megatoneladas)'].argmax()
top_pais= df['Country'][ind_top]
print(top)

print(f"El pais que genera mayor emision de Co2 es: {top_pais} con un emision de Co2 de {top}")
# Out:
# 5006302.0
# El pais que genera mayor emision de Co2 es: United States con un emision de Co2 de 5006302.0

# %%
#Se puede observar que a mayor cantidad de CO2 el tiempo de vida se reduce.
#El pais con menor emision de co2
low=df['Co2-Emissions(megatoneladas)'].min()
ind_low= df['Co2-Emissions(megatoneladas)'].argmin()
low_pais= df['Country'][ind_low]
print(low)

print(f"El pais que genera menor emision de Co2 es: {low_pais} con un emision de Co2 de {low}")
# Out:
# 1.28
# El pais que genera menor emision de Co2 es: Barbados con un emision de Co2 de 1.28

# %% [markdown]
# *H2: Producto interno bruto con calidad de educación (primaria y tercearia)*

# %%
#H2: Producto interno bruto con calidad de educacion (primaria y tercearia)
def quitar(x):
  return x.strip('$ ')

def reemplazo(x):
  return x.replace(',','')

df['GDP $'] = df['GDP $'].apply(str)
df['GDP $'] = df['GDP $'].apply(quitar)
df['GDP $']
df['GDP $'] = df['GDP $'].apply(reemplazo)
df['GDP $'] = df['GDP $'].apply(float)

matrizH2 =df.iloc[:,[0,6,7,8]]
print(matrizH2)
mediaGDP= df['GDP $'].mean()
#Ecu_med=df.loc[13, 'Co2-Emissions']
print(f'El promedio del producto interno bruto en America es {round(mediaGDP,2)} y la media del PIB del Ecuador es {df.loc[13, "GDP $"]} millones de dolares ')
# Out:
#                              Country         GDP $  \
# 0                Antigua and Barbuda  1.727759e+09
# 1                          Argentina  4.496634e+11
# 2                           Barbados  5.209000e+09
# 3                             Belize  1.879614e+09
# 4                            Bolivia  4.089532e+10
# 5                             Brazil  1.839758e+12
# 6                             Canada  1.736426e+12
# 7                              Chile  2.823182e+11
# 8                           Colombia  3.238028e+11
# 9                         Costa Rica  6.177394e+10
# 10                              Cuba  1.000230e+11
# 11                          Dominica  5.960333e+08
# 12                Dominican Republic  8.894130e+10
# 13                           Ecuador  1.074357e+11
# 14                       El Salvador  2.702264e+10
# 15                           Grenada  1.228170e+09
# 16                         Guatemala  7.671039e+10
# ...

# %%
matrizH2 =df.iloc[:,[0,6,7,8]]
print(matrizH2)
# Out:
#                              Country         GDP $  \
# 0                Antigua and Barbuda  1.727759e+09
# 1                          Argentina  4.496634e+11
# 2                           Barbados  5.209000e+09
# 3                             Belize  1.879614e+09
# 4                            Bolivia  4.089532e+10
# 5                             Brazil  1.839758e+12
# 6                             Canada  1.736426e+12
# 7                              Chile  2.823182e+11
# 8                           Colombia  3.238028e+11
# 9                         Costa Rica  6.177394e+10
# 10                              Cuba  1.000230e+11
# 11                          Dominica  5.960333e+08
# 12                Dominican Republic  8.894130e+10
# 13                           Ecuador  1.074357e+11
# 14                       El Salvador  2.702264e+10
# 15                           Grenada  1.228170e+09
# 16                         Guatemala  7.671039e+10
# ...

# %%
mediaGDP= df['GDP $'].mean()
#Ecu_med=df.loc[13, 'Co2-Emissions']
print(f'El promedio del producto interno bruto en America es {round(mediaGDP,2)} y el PIB del Ecuador es {df.loc[13, "GDP $"]} millones de dólares ')
# Out:
# El promedio del producto interno bruto en America es 872711639488.58 y el PIB del Ecuador es 107435665000.0 millones de dólares

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import matplotlib.colors

mediaPE= df['Gross primary education enrollment (%)'].mean()
print("aproximadamente los países en América invierten el: " + str(mediaPE) + "% de su producto interno bruto en educación primaria")
ecuPE=(df.loc[13, "Gross primary education enrollment (%)"])*(df.loc[13, "GDP $"])
print("Ecuador con un GDP de "+ str(df.loc[13, "GDP $"]) + "invierte "+ str(ecuPE) +'millones de dolares en educacion primaria' )

mediaTE = df['Gross tertiary education enrollment (%)'].mean()  #media de TE en america
ecuTE=(df.loc[13, "GDP $"])*(df.loc[13, 'Gross tertiary education enrollment (%)'])  #cuanto inverte Ecuador en TE
print('aproximadamente los países de América invierten el: ' +
      str(mediaTE) +"% de su producto interno bruto en educación terciaria, en donde Ecuador con un PIB de "+str(df.loc[13, "GDP $"])+'invierte '+str(ecuTE)+' millones de dolares en educacion terciaria')

#el país con el PIB más grande es el que más invierte en educación...sacar el porcentaje de PE y TE, sumarlos y comparar....
columGDP=df['GDP $']
columPE=df['Gross primary education enrollment (%)']
columTE= df['Gross tertiary education enrollment (%)']

columTotPE= (df['GDP $'])*(df['Gross primary education enrollment (%)'])
columTotTE=(df['GDP $'])*(df['Gross tertiary education enrollment (%)'])
inversionEdu= columTotPE + columTotTE
indMaxEdu= inversionEdu.argmax()
paisMayorInv=df['Country'][indMaxEdu]
print(paisMayorInv)
#Ahora, ¿Ser el país que más dinero invierte en educación es lo mismo que decir el país que más inversión destina a su educación?
porcentajeColumn=columPE + columTE
top_porcentajeColumn=porcentajeColumn.argmax()
top_pais_porcentajeColumn= df['Country'][top_porcentajeColumn]
df['inversion educacion']= inversionEdu
df['porcentaje colum'] = porcentajeColumn

print(porcentajeColumn)
print('País que mayor porcentaje de su GDP destina a la educación a pesar de no ser el que más dinero invierte, es  ')
print(top_pais_porcentajeColumn)

#grafico1
df_grafico_inversion= df.loc[:,['Country','inversion educacion']]
categoria =df_grafico_inversion['Country'].index
valores = df_grafico_inversion['inversion educacion'].values
colores = ["black", "white", "red", "blue", "green", "yellow", "orange", "pink", "purple", "brown", "gray", "gold", "silver", "turquoise", "cyan", "magenta", "fuchsia", "beige", "ivory", "sienna", "#C78F21",
    "#EA7E5D",
    "#FBB973",
    "#FF7F50",
    "#FFE5B4",
    "#FA8072",
    "#FDF5E6",
    "#D890FA",
    "#C7C4D8",
    "#ECEAE7",
    "#D9DBD9",
    "#B76E79",]
plt.figure(figsize=(10,6))
log_data = np.log(categoria)
plt.bar(range(len(log_data)),valores,color=colores)
plt.title("inversion de GDP en educacion")
plt.xlabel("país")
plt.ylabel("Dólares")


#grafico2
df_grafico_porcentaje = df.loc[:,['Country','porcentaje colum']]
categoria2 =df_grafico_porcentaje['Country'].index
valores2 = df_grafico_porcentaje['porcentaje colum'].values
colores2 = ["black", "white", "red", "blue", "green", "yellow", "orange", "pink", "purple", "brown", "gray", "gold", "silver", "turquoise", "cyan", "magenta", "fuchsia", "beige", "ivory", "sienna", "#EA7E5D",
    "#FBB973",
    "#FF7F50",
    "#FFE5B4",
    "#FA8072",
    "#FDF5E6",
    "#D890FA",
    "#C7C4D8",
    "#ECEAE7",
    "#D9DBD9",
    "#B76E79",]
plt.figure(figsize=(10,6))
plt.bar(categoria2,valores2,color=colores2)
plt.title("inversion porcentual a educacion respecto a su GDP")
plt.xlabel("país")
plt.ylabel("porcentaje %")
# Out:
# aproximadamente los países en América invierten el: 1.0494545454545454% de su producto interno bruto en educación primaria
# Ecuador con un GDP de 107435665000.0invierte 110981041944.99998millones de dolares en educacion primaria
# aproximadamente los países de América invierten el: 0.4384374999999999% de su producto interno bruto en educación terciaria, en donde Ecuador con un PIB de 107435665000.0invierte 48238613585.0 millones de dolares en educacion terciaria
# United States
# 0     1.298
# 1     1.997
# 2     1.648
# 3     1.364
# 4       NaN
# 5     1.667
# 6     1.698
# 7     1.899
# 8     1.698
# 9     1.685
# 10    1.433
# 11    1.219
# 12    1.656
# 13    1.482
# 14    1.242
# 15    2.115
# 16    1.237
# 17    1.094
# 18    1.147
# 19    1.177
# 20    1.181
# 21    1.460
# 22    1.380
# 23    1.422
# 24    1.390
# 25    1.776
# 26    1.167
# 27    1.371
# 28    1.214
# 29    1.182
# 30    1.900
# 31    1.716
# 32    1.765
# dtype: float64
# ...

# %% [markdown]
# H4: #H4: Médicos por cada 1000 con población urbana- ods3.

# %%
import pandas as pd
import geopandas as gdp
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
#variables a tomar en cuenta: Physicians per thousand  &  Population
import matplotlib.pyplot as plt
def quitar(x):
  return x.strip('$ ')

def reemplazo(x):
  return x.replace(',','')
df['Population'] = df['Population'].apply(str)
df['Population'] = df['Population'].apply(quitar)
df['Population'] = df['Population'].apply(reemplazo)
df['Population'] = round(df['Population'].apply(float),2)
df['Population']
matrizH4 =df.iloc[:,[0,14,15]]
#print(matrizH4)

mediaPob= df['Population'].mean()
totPob = df['Population'].sum()


#total de médicos en Ecuador
totMedEcu=(df.loc[13, "Population"])*(df.loc[13, "Physicians per thousand"])/1000

medicos=(df['Population'])*(df['Physicians per thousand'])/1000


df["medicos"]= medicos
df['Country'].unique()
dfalternativo = df.drop(df[df['Country'] == 'Antigua and Barbuda'].index)
dfalternativo = dfalternativo.drop(dfalternativo[dfalternativo['Country'] == 'Grenada'].index)
dfalternativo = dfalternativo.drop(dfalternativo[dfalternativo['Country'] == 'Saint Lucia'].index)
dfalternativo = dfalternativo.drop(dfalternativo[dfalternativo['Country'] == 'Barbados'].index)
dfalternativo = dfalternativo.drop(dfalternativo[dfalternativo['Country'] == 'Saint Vincent and the Grenadines'].index)
dfalternativo = dfalternativo.drop(dfalternativo[dfalternativo['Country'] == 'Dominica'].index)



print(dfalternativo)


dfalternativo['abreviatura'] = ['ARG','BLZ','BOL','BRA','CAN','CHL','COL','CRI','CU1','DOM','ECU','SLV','GTM','GUY','HTI','HND','JAM','MEX','NIC','PAN','PRY','PER','SUR','TTO','US1','URY','VEN']
dfalternativo=dfalternativo.loc[:,['medicos','abreviatura']]


#total de médicos tanto en Ecuador como en América
#print('la cantidad aproximada de médicos en Amperica Latina es de '+str(medicos) + 'y la cantidad de médicos en Ecuador es de '+str(totMedEcu))
#cuan representativa es la cantidad de médicos de Ecuador en América
#print('la cantidad de médicos en Ecuador representa el '+ str((totMedEcu/medicos)*100) + '% de medicos en América')

#Realizar un gráfico

df_2 = pd.read_excel('/content/drive/MyDrive/ciap/world-data-2023.ap2.xlsx')
americaData= df_2.iloc[[5,6,14,17,20,23,32,35,37,40,42,48,49,50,52,67,71,72,74,84,110,124,134,136,137,146,147,167,177,186,187,190]]
df_3 = gdp.read_file('/content/drive/MyDrive/ciap/custom.geo.json')
df_3 = df_3.sort_values(by='sovereignt')

print(df_3['sovereignt'].unique())

df_3 = df_3.drop(df_3[df_3['sovereignt'] == 'The Bahamas'].index)
df_3 = df_3.drop(df_3[df_3['sovereignt'] == 'United Kingdom'].index)
df_3 = df_3.drop(df_3[df_3['sovereignt'] == 'Falkland Islands'].index)
df_3 = df_3.drop(df_3[df_3['sovereignt'] == 'Puerto Rico'].index)
df_3=df_3.drop(15)


print(df_3)

datos_americaMed =  df_3.merge(dfalternativo, left_on='sov_a3',right_on='abreviatura')
print(datos_americaMed.head())

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
datos_americaMed.plot(column='medicos', cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, cax=cax)

datos_americaMed.plot()
# Out:
#                 Country  Density(P/Km2) Armed Forces size  \
# 1             Argentina              17               105
# 3                Belize              17                 2
# 4               Bolivia              11                71
# 5                Brazil              25               730
# 6                Canada               4                72
# 7                 Chile              26               122
# 8              Colombia              46               481
# 9            Costa Rica             100                10
# 10                 Cuba             106                76
# 12   Dominican Republic             225                71
# 13              Ecuador              71                41
# 14          El Salvador             313                42
# 16            Guatemala             167                43
# 17               Guyana               4                 3
# 18                Haiti             414                 0
# ...

# %% [markdown]
# ## Máscara booleana
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Condición simple

# %%
#H1: CO2 Y CALIDAD DE VIDA-ods3.

#H2: GDP con educación -ODS4y8   #nivel socioeconómico,

#H3: tamaño/densidad país con fuerza militar-ODS16?,

#H4: Médicos por cada 1000 con población urbana- ods3.

#H5: gasto de bolsillo en salud con la mortalidad de niños - ODS3
